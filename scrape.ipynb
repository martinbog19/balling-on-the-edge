# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import calendar
import time
months = [month.lower() for month in calendar.month_name[1:]]

# %% [markdown]
# # Scraping standings

# %%
# This function scrapes the division standings and outputs a dataframe of the standings for an input year
def Standings(year):


    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_standings.html'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html')
    while soup.find(class_ = 'thead') is not None:
        soup.find(class_ = 'thead').decompose()
    east_table, west_table = [t for t in soup.find_all('table') if 'divs_standings' in t.get('id')]

    east = pd.read_html(str(east_table))[0].rename(columns = {'Eastern Conference': 'Team'})
    east.insert(1, 'Tm', [str(x).split('/')[2] for x in east_table.find_all('a', href = True)])
    west = pd.read_html(str(west_table))[0].rename(columns = {'Western Conference': 'Team'})
    west.insert(1, 'Tm', [str(x).split('/')[2] for x in west_table.find_all('a', href = True)])

    standings = pd.concat([east, west])
    standings['Team'] = standings['Team'].str.replace('*', '', regex = False)
    standings.insert(2, 'Year', len(standings) * [year])

    return standings.sort_values('W/L%', ascending = False).drop(columns = ['GB']).reset_index(drop = True)

# %%
Standings(1980)
# Out:
#                       Team   Tm  Year   W   L   W/L%   PS/G   PA/G   SRS
# 0           Boston Celtics  BOS  1980  61  21  0.744  113.5  105.7  7.37
# 1       Los Angeles Lakers  LAL  1980  60  22  0.732  115.1  109.2  5.40
# 2       Philadelphia 76ers  PHI  1980  59  23  0.720  109.1  104.9  4.04
# 3      Seattle SuperSonics  SEA  1980  56  26  0.683  108.5  103.8  4.24
# 4             Phoenix Suns  PHO  1980  55  27  0.671  111.1  107.5  3.25
# 5            Atlanta Hawks  ATL  1980  50  32  0.610  104.5  101.6  2.83
# 6          Milwaukee Bucks  MIL  1980  49  33  0.598  110.1  106.1  3.57
# 7        Kansas City Kings  KCK  1980  47  35  0.573  108.0  104.9  2.82
# 8        San Antonio Spurs  SAS  1980  41  41  0.500  119.4  119.7 -0.24
# 9          Houston Rockets  HOU  1980  41  41  0.500  110.8  110.6  0.27
# 10         New York Knicks  NYK  1980  39  43  0.476  114.0  115.1 -0.96
# 11      Washington Bullets  WSB  1980  39  43  0.476  107.0  109.5 -2.27
# 12  Portland Trail Blazers  POR  1980  38  44  0.463  102.5  103.3 -0.87
# 13          Indiana Pacers  IND  1980  37  45  0.451  111.2  111.9 -0.54
# 14     Cleveland Cavaliers  CLE  1980  37  45  0.451  114.1  113.8  0.43
# 15      San Diego Clippers  SDC  1980  35  47  0.427  107.6  111.7 -3.97
# 16         New Jersey Nets  NJN  1980  34  48  0.415  108.3  109.5 -0.98
# 17          Denver Nuggets  DEN  1980  30  52  0.366  108.3  112.7 -4.22
# 18           Chicago Bulls  CHI  1980  30  52  0.366  107.5  110.2 -2.63
# 19               Utah Jazz  UTA  1980  24  58  0.293  102.4  108.4 -5.71
# 20   Golden State Warriors  GSW  1980  24  58  0.293  103.6  108.0 -4.20
# 21         Detroit Pistons  DET  1980  16  66  0.195  108.9  117.2 -7.57

# %%
Standings(2023)
# Out:
#                       Team   Tm  Year   W   L   W/L%   PS/G   PA/G   SRS
# 0          Milwaukee Bucks  MIL  2023  58  24  0.707  116.9  113.3  3.61
# 1           Boston Celtics  BOS  2023  57  25  0.695  117.9  111.4  6.38
# 2       Philadelphia 76ers  PHI  2023  54  28  0.659  115.2  110.9  4.37
# 3           Denver Nuggets  DEN  2023  53  29  0.646  115.8  112.5  3.04
# 4      Cleveland Cavaliers  CLE  2023  51  31  0.622  112.3  106.9  5.23
# 5        Memphis Grizzlies  MEM  2023  51  31  0.622  116.9  113.0  3.60
# 6         Sacramento Kings  SAC  2023  48  34  0.585  120.7  118.1  2.30
# 7          New York Knicks  NYK  2023  47  35  0.573  116.0  113.1  2.99
# 8             Phoenix Suns  PHO  2023  45  37  0.549  113.6  111.6  2.08
# 9            Brooklyn Nets  BRK  2023  45  37  0.549  113.4  112.5  1.03
# 10              Miami Heat  MIA  2023  44  38  0.537  109.5  109.8 -0.13
# 11   Golden State Warriors  GSW  2023  44  38  0.537  118.9  117.1  1.66
# 12    Los Angeles Clippers  LAC  2023  44  38  0.537  113.6  113.1  0.31
# 13      Los Angeles Lakers  LAL  2023  43  39  0.524  117.2  116.6  0.43
# 14    New Orleans Pelicans  NOP  2023  42  40  0.512  114.4  112.5  1.63
# 15  Minnesota Timberwolves  MIN  2023  42  40  0.512  115.8  115.8 -0.22
# 16         Toronto Raptors  TOR  2023  41  41  0.500  112.9  111.4  1.59
# 17           Atlanta Hawks  ATL  2023  41  41  0.500  118.4  118.1  0.32
# 18   Oklahoma City Thunder  OKC  2023  40  42  0.488  117.5  116.4  0.96
# 19           Chicago Bulls  CHI  2023  40  42  0.488  113.1  111.8  1.37
# 20        Dallas Mavericks  DAL  2023  38  44  0.463  114.2  114.1 -0.14
# 21               Utah Jazz  UTA  2023  37  45  0.451  117.1  118.0 -1.03
# 22      Washington Wizards  WAS  2023  35  47  0.427  113.2  114.4 -1.06
# 23          Indiana Pacers  IND  2023  35  47  0.427  116.3  119.5 -2.91
# 24           Orlando Magic  ORL  2023  34  48  0.415  111.4  114.0 -2.39
# 25  Portland Trail Blazers  POR  2023  33  49  0.402  113.4  117.4 -3.96
# 26       Charlotte Hornets  CHO  2023  27  55  0.329  111.0  117.2 -5.89
# 27         Houston Rockets  HOU  2023  22  60  0.268  110.7  118.6 -7.62
# 28       San Antonio Spurs  SAS  2023  22  60  0.268  113.0  123.1 -9.82
# 29         Detroit Pistons  DET  2023  17  65  0.207  110.3  118.5 -7.73

# %% [markdown]
# # Scraping player stats (basic & advanced)

# %%
def PlayerStats(year) :

    def single_team(df) :
        # For an input player, this function returns only a row with total stats and the latest team of the player
        if len(df) > 1:
            row = df[df['Tm'] == 'TOT']
            row['Tm'] = df['Tm'].values[-1]
            return row
        else :
            return df

    # Scrape per game stats -- PTS, TRB, AST, ...
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html')
    table = soup.find('table')
    while table.find(class_ = 'thead') is not None :
        table.find(class_ = 'thead').decompose()
    data_pg = pd.read_html(str(table))[0].drop(columns = ['Rk'])
    data_pg.insert(1, 'href', [str(x).split('.html')[0].split('/')[-1] for x in table.find_all('a', href = True) if 'players' in str(x)])
    data_pg = data_pg.groupby('href').apply(single_team).reset_index(drop = True)
    data_pg['Player'] = data_pg['Player'].str.replace('*', '', regex = False)

    # Scrape advanced stats -- PER, BPM, WS, VORP, ...
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_advanced.html'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html')
    table = soup.find('table')
    while table.find(class_ = 'thead') is not None :
        table.find(class_ = 'thead').decompose()
    data_adv = pd.read_html(str(table))[0]
    data_adv = data_adv.drop(columns = ['Rk'] + [x for x in data_adv.columns if 'Unnamed' in x])
    data_adv.insert(1, 'href', [str(x).split('.html')[0].split('/')[-1] for x in table.find_all('a', href = True) if 'players' in str(x)])
    data_adv = data_adv.groupby('href').apply(single_team).reset_index(drop = True)
    data_adv['Player'] = data_adv['Player'].str.replace('*', '', regex = False)

    # Merge per game and advanced stats together
    data = data_pg.merge(data_adv, on = ['Player', 'href'], suffixes = ('', '_y'))
    data = data.drop(columns = [col for col in data.columns if '_y' in col]).reset_index(drop = True) # Delete duplicated columns
    data.insert(2, 'Year', len(data) * [year])

    if len(data) != len(data_pg) or len(data) != len(data_adv):
        Warning('Merge between per game and advanced stats is not 1:1 !!')

    return data

# %%
PlayerStats(2023)
# Out:
#                Player       href  Year Pos  Age   Tm   G  GS    MP   FG  ...  \
# 0    Precious Achiuwa  achiupr01  2023   C   23  TOR  55  12  20.7  3.6  ...
# 1        Steven Adams  adamsst01  2023   C   29  MEM  42  42  27.0  3.7  ...
# 2         Bam Adebayo  adebaba01  2023   C   25  MIA  75  75  34.6  8.0  ...
# 3        Ochai Agbaji  agbajoc01  2023  SG   22  UTA  59  22  20.5  2.8  ...
# 4        Santi Aldama  aldamsa01  2023  PF   22  MEM  77  20  21.8  3.2  ...
# ..                ...        ...   ...  ..  ...  ...  ..  ..   ...  ...  ...
# 534    Thaddeus Young  youngth01  2023  PF   34  TOR  54   9  14.7  2.0  ...
# 535        Trae Young  youngtr01  2023  PG   24  ATL  73  73  34.8  8.2  ...
# 536    Omer Yurtseven  yurtsom01  2023   C   24  MIA   9   0   9.2  1.8  ...
# 537       Cody Zeller  zelleco01  2023   C   30  MIA  15   2  14.5  2.5  ...
# 538       Ivica Zubac  zubaciv01  2023   C   25  LAC  76  76  28.6  4.3  ...
#
#      TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0    11.4  19.4  0.8  1.4  2.2  0.093  -1.4  -0.8 -2.3  -0.1
# 1    19.8  14.6  1.3  2.1  3.4  0.144  -0.3   0.9  0.6   0.7
# 2    12.7  25.2  3.6  3.8  7.4  0.137   0.8   0.8  1.5   2.3
# 3     9.0  15.8  0.9  0.4  1.3  0.053  -1.7  -1.4 -3.0  -0.3
# 4     9.3  16.0  2.1  2.4  4.6  0.130  -0.3   0.8  0.5   1.1
# ..    ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 534  16.7  13.5  0.7  1.1  1.8  0.109  -1.8   1.9  0.1   0.4
# 535  15.2  32.6  5.3  1.4  6.7  0.126   5.3  -2.0  3.3   3.4
# 536  11.9  18.0  0.2  0.1  0.3  0.159  -2.5  -1.5 -3.9   0.0
# 537  15.8  18.1  0.4  0.3  0.7  0.147  -2.0  -0.7 -2.8   0.0
# 538  15.9  14.8  3.8  2.9  6.7  0.149  -1.1   0.2 -0.9   0.6
#
# [539 rows x 51 columns]

# %%
PlayerStats(1980)
# Out:
#                   Player       href  Year Pos  Age   Tm   G    GS    MP    FG  \
# 0    Kareem Abdul-Jabbar  abdulka01  1980   C   32  LAL  82   NaN  38.3  10.2
# 1          Tom Abernethy  abernto01  1980  PF   25  GSW  67   NaN  18.2   2.3
# 2            Alvan Adams  adamsal01  1980   C   25  PHO  75   NaN  28.9   6.2
# 3         Tiny Archibald  architi01  1980  PG   31  BOS  80  80.0  35.8   4.8
# 4          Dennis Awtrey  awtrede01  1980   C   31  CHI  26   NaN  21.5   1.0
# ..                   ...        ...   ...  ..  ...  ...  ..   ...   ...   ...
# 282         Bubba Wilson  wilsobu01  1980  SG   24  GSW  16   NaN   8.9   0.4
# 283          Rick Wilson  wilsori01  1980  SG   23  ATL   5   NaN  11.8   0.4
# 284        Brian Winters  wintebr01  1980  SG   27  MIL  80   NaN  32.8   6.7
# 285         Larry Wright  wrighla01  1980  PG   25  WSB  76   NaN  16.9   3.0
# 286            Tony Zeno   zenoto01  1980  SF   22  IND   8   NaN   7.4   0.8
#
#      ...  TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 0    ...  15.7  24.1  9.5  5.3  14.8  0.227   4.8   2.4  7.2   7.3
# 1    ...   9.9  13.3  1.2  0.8   2.0  0.080  -1.0  -0.2 -1.2   0.2
# 2    ...  18.2  21.9  3.1  3.9   7.0  0.155   1.7   1.9  3.6   3.1
# 3    ...  19.7  17.0  5.9  2.9   8.9  0.148   1.4  -0.3  1.1   2.3
# 4    ...  24.8   7.9  0.1  0.5   0.6  0.053  -2.3   0.9 -1.4   0.1
# ..   ...   ...   ...  ...  ...   ...    ...   ...   ...  ...   ...
# 282  ...  22.4  10.3 -0.2  0.0  -0.2 -0.064  -4.4  -0.9 -5.3  -0.2
# 283  ...  32.5  17.1 -0.3  0.1  -0.2 -0.146  -4.1   0.0 -4.1   0.0
# 284  ...  13.3  21.1  3.6  2.6   6.2  0.113   0.3  -0.2  0.2   1.4
# 285  ...  16.5  20.1  0.8  1.0   1.8  0.069  -1.1   0.1 -1.0   0.3
# 286  ...  29.1  20.3 -0.3  0.1  -0.2 -0.160  -6.4  -0.1 -6.5  -0.2
#
# [287 rows x 51 columns]

# %% [markdown]
# # Opening day roster

# %%
# This function creates a dictionary for any input year, where the key is the name of the team and the item is a list of players on the opening day roster
def OpeningDayRoster(year) :

    # Explore the page with all teams and links to rosters
    url = f'https://basketball.realgm.com/nba/teams/{year}'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html')
    # Make a list of all teams alongside their unique identifier
    teams = [(x['href'].split('/')[4], x['href'].split('/')[3]) for x in soup.find_all('a', href = True) if '/teams/' in str(x) and 'Rosters' in str(x) and str(year) in str(x)]
    
    # Loop along each team
    dict = {}
    for i, tm in teams :
        # Scrape the opening day roster table of the looped team and assign the list of players to the dictionary
        url = f'https://basketball.realgm.com/nba/teams/{tm}/{i}/Rosters/Opening_Day/{year}'
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html')
        table = soup.find_all('table')[6]
        dict[' '.join(tm.split('-'))] = pd.read_html(str(table))[0]['Player'].to_list()

    return dict

# %%
OpeningDayRoster(2023)
# Out:
# {'Boston Celtics': ['Malcolm Brogdon',
#   'Jaylen Brown',
#   'J.D. Davison',
#   'Danilo Gallinari',
#   'Blake Griffin',
#   'Sam Hauser',
#   'Al Horford',
#   'Justin Jackson',
#   'Mfiondu Kabengele',
#   'Luke Kornet',
#   'Payton Pritchard',
#   'Marcus Smart',
#   'Jayson Tatum',
#   'Noah Vonleh',
#   'Derrick White',
#   'Grant Williams',
#   'Robert Williams'],
#  'Brooklyn Nets': ['Nicolas Claxton',
#   'Seth Curry',
#   'David Duke',
#   'Kevin Durant',
#   'Kessler Edwards',
#   'Joe Harris',
#   'Kyrie Irving',
#   'Patty Mills',
#   'Markieff Morris',
#   "Royce O'Neale",
#   "Day'Ron Sharpe",
#   'Ben Simmons',
#   'Edmond Sumner',
#   'Cam Thomas',
#   'T.J. Warren',
#   'Yuta Watanabe',
#   'Alondes Williams'],
#  'New York Knicks': ['Ryan Arcidiacono',
#   'R.J. Barrett',
#   'Jalen Brunson',
#   'Evan Fournier',
#   'Quentin Grimes',
#   'Isaiah Hartenstein',
#   'Feron Hunt',
#   'Trevor Keels',
#   'Miles McBride',
#   'Svi Mykhailiuk',
#   'Immanuel Quickley',
#   'Julius Randle',
#   'Cam Reddish',
#   'Mitchell Robinson',
#   'Derrick Rose',
#   'Jericho Sims',
#   'Obi Toppin'],
#  'Philadelphia Sixers': ['Julian Champagnie',
#   'Joel Embiid',
#   'Michael Foster, Jr.',
#   'James Harden',
#   'Montrezl Harrell',
#   'Tobias Harris',
#   'Danuel House',
#   'Furkan Korkmaz',
#   'Tyrese Maxey',
#   "De'Anthony Melton",
#   'Shake Milton',
#   'Georges Niang',
#   'Paul Reed, Jr.',
#   'Jaden Springer',
#   'Matisse Thybulle',
#   'P.J. Tucker'],
#  'Toronto Raptors': ['Precious Achiuwa',
#   'OG Anunoby',
#   'Dalano Banton',
#   'Scottie Barnes',
#   'Khem Birch',
#   'Chris Boucher',
#   'Justin Champagnie',
#   'Jeff Dowtin',
#   'Malachi Flynn',
#   'Ron Harper',
#   'Juancho Hernangomez',
#   'Christian Koloko',
#   'Otto Porter',
#   'Pascal Siakam',
#   'Gary Trent, Jr.',
#   'Fred VanVleet',
#   'Thaddeus Young'],
#  'Chicago Bulls': ['Kostas Antetokounmpo',
#   'Lonzo Ball',
#   'Tony Bradley',
#   'Alex Caruso',
#   'DeMar DeRozan',
#   'Ayo Dosunmu',
#   'Goran Dragic',
#   'Andre Drummond',
#   'Javonte Green',
#   'Malcolm Hill',
#   'Derrick Jones',
#   'Zach LaVine',
#   'Marko Simonovic',
#   'Dalen Terry',
#   'Nikola Vucevic',
#   'Coby White',
#   'Patrick Williams'],
#  'Cleveland Cavaliers': ['Jarrett Allen',
#   'Mamadi Diakite',
#   'Darius Garland',
#   'Caris LeVert',
#   'Robin Lopez',
#   'Kevin Love',
#   'Donovan Mitchell',
#   'Evan Mobley',
#   'Isaiah Mobley',
#   'Raulzinho Neto',
#   'Isaac Okoro',
#   'Cedi Osman',
#   'Ricky Rubio',
#   'Lamar Stevens',
#   'Dean Wade',
#   'Dylan Windler'],
#  'Detroit Pistons': ['Marvin Bagley III',
#   'Saddiq Bey',
#   'Buddy Boeheim',
#   'Bojan Bogdanovic',
#   'Alec Burks',
#   'Cade Cunningham',
#   'Hamidou Diallo',
#   'Jalen Duren',
#   'Killian Hayes',
#   'Jaden Ivey',
#   'Cory Joseph',
#   'Braxton Key',
#   'Kevin Knox',
#   'Isaiah Livers',
#   'Rodney McGruder',
#   'Nerlens Noel',
#   'Isaiah Stewart II'],
#  'Indiana Pacers': ['Goga Bitadze',
#   'Oshae Brissett',
#   'Kendall Brown',
#   'Chris Duarte',
#   'Tyrese Haliburton',
#   'Buddy Hield',
#   'Isaiah Jackson',
#   'James Johnson',
#   'Bennedict Mathurin',
#   'T.J. McConnell',
#   'Andrew Nembhard',
#   'Aaron Nesmith',
#   'Trevelin Queen',
#   'Jalen Smith',
#   'Terry Taylor',
#   'Daniel Theis',
#   'Myles Turner'],
#  'Milwaukee Bucks': ['Thanasis Antetokounmpo',
#   'Giannis Antetokounmpo',
#   'Grayson Allen',
#   'MarJon Beauchamp',
#   'Jevon Carter',
#   'Pat Connaughton',
#   'A.J. Green',
#   'George Hill',
#   'Jrue Holiday',
#   'Serge Ibaka',
#   'Joe Ingles',
#   'Brook Lopez',
#   'Sandro Mamukelashvili',
#   'Wesley Matthews',
#   'Khris Middleton',
#   'Jordan Nwora',
#   'Bobby Portis'],
#  'Atlanta Hawks': ['Bogdan Bogdanovic',
#   'John Collins',
#   'Jarrett Culver',
#   'Trent Forrest',
#   'A.J. Griffin, Jr.',
#   'Aaron Holiday',
#   'Justin Holiday',
#   "De'Andre Hunter",
#   'Jalen Johnson',
#   'Frank Kaminsky',
#   'Vit Krejci',
#   'Tyrese Martin',
#   'Dejounte Murray',
#   'Clint Capela',
#   'Onyeka Okongwu',
#   'Trae Young'],
#  'Charlotte Hornets': ['LaMelo Ball',
#   'James Bouknight',
#   'Gordon Hayward',
#   'Kai Jones',
#   'Theo Maledon',
#   'Cody Martin',
#   'Jalen McDaniels',
#   'Bryce McGowens',
#   'Kelly Oubre, Jr.',
#   'Mason Plumlee',
#   'Nick Richards',
#   'Terry Rozier',
#   'Dennis Smith',
#   'J.T. Thor',
#   'P.J. Washington',
#   'Mark Williams'],
#  'Miami Heat': ['Bam Adebayo',
#   'Jimmy Butler',
#   'Jamal Cain',
#   'Dewayne Dedmon',
#   'Udonis Haslem',
#   'Tyler Herro',
#   'Haywood Highsmith',
#   'Nikola Jovic',
#   'Kyle Lowry',
#   'Caleb Martin',
#   'Victor Oladipo',
#   'Duncan Robinson',
#   'Dru Smith',
#   'Max Strus',
#   'Gabe Vincent',
#   'Omer Yurtseven'],
#  'Orlando Magic': ['Cole Anthony',
#   'Mohamed Bamba',
#   'Paolo Banchero',
#   'Bol Bol',
#   'Wendell Carter, Jr.',
#   'Markelle Fultz',
#   'R.J. Hampton',
#   'Gary Harris',
#   'Kevon Harris',
#   'Caleb Houstan',
#   'Jonathan Isaac',
#   'Chuma Okeke',
#   'Terrence Ross',
#   'Admiral Schofield',
#   'Jalen Suggs',
#   'Franz Wagner',
#   'Moe Wagner'],
#  'Washington Wizards': ['Deni Avdija',
#   'Will Barton',
#   'Bradley Beal',
#   'Vernon Carey, Jr.',
#   'Johnny Davis',
#   'Daniel Gafford',
#   'Taj Gibson',
#   'Anthony Gill',
#   'Jordan Goodwin',
#   'Rui Hachimura',
#   'Corey Kispert',
#   'Kyle Kuzma',
#   'Monte Morris',
#   'Kristaps Porzingis',
#   'Jordan Schakel',
#   'Isaiah Todd',
#   'Delon Wright'],
#  'Denver Nuggets': ['Christian Braun',
#   'Bruce Brown, Jr.',
#   'Kentavious Caldwell-Pope',
#   'Vlatko Cancar',
#   'Collin Gillespie',
#   'Aaron Gordon',
#   'Jeff Green',
#   'Bones Hyland',
#   'Nikola Jokic',
#   'DeAndre Jordan',
#   'Jamal Murray',
#   'Zeke Nnaji',
#   'Michael Porter, Jr.',
#   'Davon Reed',
#   'Ish Smith',
#   'Peyton Watson',
#   'Jack White'],
#  'Minnesota Timberwolves': ['Kyle Anderson',
#   'Anthony Edwards',
#   'Bryn Forbes',
#   'Luka Garza',
#   'Rudy Gobert',
#   'Nathan Knight',
#   'Jaden McDaniels',
#   'Jordan McLaughlin',
#   'Josh Minott',
#   'Wendell Moore, Jr.',
#   'Jaylen Nowell',
#   'Naz Reid',
#   'Austin Rivers',
#   "D'Angelo Russell",
#   'Karl-Anthony Towns',
#   'Taurean Prince'],
#  'Oklahoma City Thunder': ['Darius Bazley',
#   'Ousmane Dieng',
#   'Luguentz Dort',
#   'Josh Giddey',
#   'Shai Gilgeous-Alexander',
#   'Chet Holmgren',
#   'Isaiah Joe',
#   'Tre Mann',
#   'Mike Muscala',
#   'Eugene Omoruyi',
#   'Aleksej Pokusevski',
#   'Jeremiah Robinson-Earl',
#   'Lindy Waters III',
#   'Aaron Wiggins',
#   'Jalen Williams',
#   'Jaylin Williams',
#   'Kenrich Williams'],
#  'Portland Trail Blazers': ['Greg Brown III',
#   'Drew Eubanks',
#   'Jerami Grant',
#   'Josh Hart',
#   'Keon Johnson',
#   'Damian Lillard',
#   'Nassir Little',
#   'Jusuf Nurkic',
#   'Gary Payton II',
#   'Olivier Sarr',
#   'Shaedon Sharpe',
#   'Anfernee Simons',
#   'Jabari Walker',
#   'Trendon Watford',
#   'Justise Winslow'],
#  'Utah Jazz': ['Ochai Agbaji',
#   'Udoka Azubuike',
#   'Malik Beasley',
#   'Leandro Bolmaro',
#   'Jordan Clarkson',
#   'Mike Conley',
#   'Simone Fontecchio',
#   'Rudy Gay',
#   'Talen Horton-Tucker',
#   'Johnny Juzang',
#   'Walker Kessler',
#   'Lauri Markkanen',
#   'Kelly Olynyk',
#   'Micah Potter',
#   'Collin Sexton',
#   'Jarred Vanderbilt',
#   'Nickeil Alexander-Walker'],
#  'Golden State Warriors': ['Patrick Baldwin, Jr.',
#   'Stephen Curry',
#   'Donte DiVincenzo',
#   'Draymond Green',
#   'JaMychal Green',
#   'Andre Iguodala',
#   'Ty Jerome',
#   'Jonathan Kuminga',
#   'Anthony Lamb',
#   'Kevon Looney',
#   'Moses Moody',
#   'Jordan Poole',
#   'Ryan Rollins',
#   'Klay Thompson',
#   'Andrew Wiggins',
#   'James Wiseman'],
#  'Los Angeles Clippers': ['Nicolas Batum',
#   'B.J. Boston, Jr.',
#   'Moses Brown',
#   'Amir Coffey',
#   'Robert Covington',
#   'Moussa Diabate',
#   'Paul George',
#   'Reggie Jackson',
#   'Luke Kennard',
#   'Kawhi Leonard',
#   'Terance Mann',
#   'Marcus Morris',
#   'Norman Powell',
#   'Jason Preston',
#   'John Wall',
#   'Ivica Zubac'],
#  'Los Angeles Lakers': ['Juan Toscano-Anderson',
#   'Patrick Beverley',
#   'Troy Brown, Jr.',
#   'Thomas Bryant',
#   'Max Christie',
#   'Anthony Davis',
#   'Wenyen Gabriel',
#   'LeBron James',
#   'Damian Jones',
#   'Kendrick Nunn',
#   'Scotty Pippen, Jr.',
#   'Austin Reaves',
#   'Matt Ryan',
#   'Dennis Schroder',
#   'Cole Swider',
#   'Lonnie Walker',
#   'Russell Westbrook'],
#  'Phoenix Suns': ['Deandre Ayton',
#   'Bismack Biyombo',
#   'Devin Booker',
#   'Mikal Bridges',
#   'Torrey Craig',
#   'Jae Crowder',
#   'Cameron Johnson',
#   'Jock Landale',
#   'Damion Lee',
#   'Josh Okogie',
#   'Chris Paul',
#   'Cameron Payne',
#   'Dario Saric',
#   'Landry Shamet',
#   'Ish Wainright',
#   'Duane Washington, Jr.'],
#  'Sacramento Kings': ['Harrison Barnes',
#   'Terence Davis',
#   'Matt Dellavedova',
#   'Keon Ellis',
#   "De'Aaron Fox",
#   'Richaun Holmes',
#   'Kevin Huerter',
#   'Alex Len',
#   'Trey Lyles',
#   'Chimezie Metu',
#   'Davion Mitchell',
#   'Chima Moneke',
#   'Malik Monk',
#   'Keegan Murray',
#   'KZ Okpala',
#   'Neemias Queta',
#   'Domantas Sabonis'],
#  'Dallas Mavericks': ['Davis Bertans',
#   'Reggie Bullock',
#   'Facundo Campazzo',
#   'Spencer Dinwiddie',
#   'Luka Doncic',
#   'Tyler Dorsey',
#   'Dorian Finney-Smith',
#   'Josh Green',
#   'Tim Hardaway Jr.',
#   'Jaden Hardy',
#   'Maxi Kleber',
#   'JaVale McGee',
#   'Frank Ntilikina',
#   'Theo Pinson',
#   'Dwight Powell',
#   'Christian Wood',
#   'McKinley Wright IV'],
#  'Houston Rockets': ['Josh Christopher',
#   'Darius Days',
#   'Tari Eason',
#   'Bruno Fernando',
#   'Usman Garuba',
#   'Eric Gordon',
#   'Jalen Green',
#   'Trevor Hudgins',
#   'Boban Marjanovic',
#   'K.J. Martin',
#   'Garrison Mathews',
#   'Daishen Nix',
#   'Kevin Porter, Jr.',
#   'Alperen Sengun',
#   'Jabari Smith, Jr.',
#   "Jae'sean Tate",
#   'TyTy Washington, Jr.'],
#  'Memphis Grizzlies': ['Steven Adams',
#   'Santi Aldama',
#   'Desmond Bane',
#   'Dillon Brooks',
#   'Kennedy Chandler',
#   'Brandon Clarke',
#   'Danny Green',
#   'Jaren Jackson, Jr.',
#   'Tyus Jones',
#   'John Konchar',
#   'Jake LaRavia',
#   'Kenny Lofton, Jr.',
#   'Ja Morant',
#   'David Roddy',
#   'Xavier Tillman, Sr.',
#   'Ziaire Williams',
#   'Vincent Williams, Jr.'],
#  'New Orleans Pelicans': ['Jose Alvarado',
#   'Dyson Daniels',
#   "Devonte' Graham",
#   'Jaxson Hayes',
#   'Willy Hernangomez',
#   'Brandon Ingram',
#   'Herb Jones',
#   'Kira Lewis, Jr.',
#   'E.J. Liddell',
#   'Naji Marshall',
#   'C.J. McCollum',
#   'Trey Murphy III',
#   'Larry Nance, Jr.',
#   'Dereon Seabron',
#   'Garrett Temple',
#   'Jonas Valanciunas',
#   'Zion Williamson'],
#  'San Antonio Spurs': ['Dominick Barlow',
#   'Keita Bates-Diop',
#   'Malaki Branham',
#   'Zach Collins',
#   'Gorgui Dieng',
#   'Jordan Hall',
#   'Keldon Johnson',
#   'Tre Jones',
#   'Romeo Langford',
#   'Doug McDermott',
#   'Jakob Poeltl',
#   'Joshua Primo',
#   'Josh Richardson',
#   'Isaiah Roby',
#   'Jeremy Sochan',
#   'Devin Vassell',
#   'Blake Wesley']}

# %%
table = [t for t in soup.find_all('table') if t.get('class') == ['tablesaw']][0]

# %%
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')

# %%
pd.read_html(str(table))
# Out:
# [              Player    Pos    HT   WT    Birth Date  Age     Pre-Draft Team  \
#  0    Nicolas Claxton      C  6-11  215  Apr 17, 1999   23            Georgia
#  1         Seth Curry     PG   6-1  185  Aug 23, 1990   32               Duke
#  2         David Duke     SG   6-4  204  Oct 13, 1999   23         Providence
#  3       Kevin Durant  SF/SG  6-11  240  Sep 29, 1988   34              Texas
#  4    Kessler Edwards     SF   6-7  203   Aug 9, 2000   22         Pepperdine
#  5         Joe Harris    G-F   6-6  220   Sep 6, 1991   31           Virginia
#  6       Kyrie Irving     PG   6-2  195  Mar 23, 1992   30               Duke
#  7        Patty Mills     PG   6-2  180  Aug 11, 1988   34       Saint Mary's
#  8    Markieff Morris     PF   6-9  245   Sep 2, 1989   33             Kansas
#  9      Royce O'Neale     SF   6-6  226   Jun 5, 1993   29             Baylor
#  10    Day'Ron Sharpe      C   6-9  265   Nov 6, 2001   20     North Carolina
#  11       Ben Simmons    G-F  6-10  240  Jul 20, 1996   26                LSU
#  12     Edmond Sumner     SG   6-4  196  Dec 31, 1995   26             Xavier
#  13        Cam Thomas     PG   6-3  210  Oct 13, 2001   21                LSU
#  14       T.J. Warren     PF   6-8  220   Sep 5, 1993   29           NC State
#  15     Yuta Watanabe    G-F   6-9  215  Oct 13, 1994   28  George Washington
#  16  Alondes Williams     SG   6-4  210  Jun 19, 1999   23        Wake Forest
#
#      YOS                               Draft Status
#  0     3           2019 2nd Rnd, #31, Brooklyn Nets
#  1     9                  2013 NBA Draft, Undrafted
#  2     1                  2021 NBA Draft, Undrafted
#  3    15      2007 1st Rnd, #2, Seattle SuperSonics
#  4     1           2021 2nd Rnd, #44, Brooklyn Nets
#  5     8     2014 2nd Rnd, #33, Cleveland Cavaliers
#  6    11      2011 1st Rnd, #1, Cleveland Cavaliers
#  7    13  2009 2nd Rnd, #55, Portland Trail Blazers
#  8    11            2011 1st Rnd, #13, Phoenix Suns
#  9     5                  2015 NBA Draft, Undrafted
#  10    1            2021 1st Rnd, #29, Phoenix Suns
#  11    6      2016 1st Rnd, #1, Philadelphia Sixers
#  12    4    2017 2nd Rnd, #52, New Orleans Pelicans
#  13    1           2021 1st Rnd, #27, Brooklyn Nets
#  14    8            2014 1st Rnd, #14, Phoenix Suns
#  15    4                  2018 NBA Draft, Undrafted
#  16    0                  2022 NBA Draft, Undrafted  ]

# %%
OpeningDayRoster(2023)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 OpeningDayRoster(2023)
#
# Cell In[4], line 19, in OpeningDayRoster(year)
#      17     soup = BeautifulSoup(page.content, 'html')
#      18     table = soup.find_all('table')[4]
# ---> 19     dict[' '.join(tm.split('-'))] = pd.read_html(str(table))[0]['Player'].to_list()
#      21 return dict
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Player'

# %%
# Loop along each team
dict = {}
for i, tm in teams[0:2] :
    # Scrape the opening day roster table of the looped team and assign the list of players to the dictionary
    url = f'https://basketball.realgm.com/nba/teams/{tm}/{i}/Rosters/Opening_Day/2023'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html')
    table = soup.find_all('table')[4]
    #dict[' '.join(tm.split('-'))] = pd.read_html(str(table))[0]['Player'].to_list()

# %%
str(soup)
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js"> <!--<![endif]-->\n<head>\n<!-- Google tag (gtag.js) -->\n<script async="" src="https://www.googletagmanager.com/gtag/js?id=G-EE4QGPXB83"></script>\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'G-EE4QGPXB83\');\r\n</script><meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n<title>Brooklyn Nets Opening Day Roster - RealGM</title>\n<meta content="https://www.facebook.com/RealGM" property="article:publisher"/>\n<meta content="305642309526726" property="fb:app_id"/>\n<meta content="Brooklyn Nets, nba, scores, news, schedule, depth charts" name="keywords"/>\n<meta content="Brooklyn Nets scores, news, schedule, players, stats, rumors, depth charts and more on RealGM.com" name="description"/>\n<meta content="nba_teams_rosters_opening_day" property="rgm:pageid"/>\n<meta content="2023-11-01 00:30:54" property="rgm:datetime"/>\n<meta content="width=device-width, initial-scale=1, maximum-scale=1.25" name="viewport"/>\n<link href="/css/normalize.min.css" rel="stylesheet"/>\n<link href="/css/main.v7.css" rel="stylesheet"/>\n<script src="/js/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>\n<script src="/js/vendor/jquery-1.11.0.min.js"></script>\n<link href="/css/tablesaw.css?v1" rel="stylesheet"/>\n<script src="/js/vendor/tablesaw.js?v1"></script>\n<script>\nwindow.grunticon=function(e){if(e&&3===e.length){var t=window,n=!(!t.document.createElementNS||!t.document.createElementNS("https://www.w3.org/2000/svg","svg").createSVGRect||!document.implementation.hasFeature("https://www.w3.org/TR/SVG11/feature#Image","1.1")||window.opera&&-1===navigator.userAgent.indexOf("Chrome")),o=function(o){var r=t.document.createElement("link"),a=t.document.getElementsByTagName("script")[0];r.rel="stylesheet",r.href=e[o&&n?0:o?1:2],a.parentNode.insertBefore(r,a)},r=new t.Image;r.onerror=function(){o(!1)},r.onload=function(){o(1===r.width&&1===r.height)},r.src="..."}};\ngrunticon(["/css/icons.data.svg.css", "/css/icons.data.png.css", "/css/icons.fallback.css"]);\n</script>\n<noscript><link href="/css/icons.fallback.css" rel="stylesheet"/></noscript>\n<link href="/css/ui/jquery-ui.min.css" rel="stylesheet"/>\n<script src="/js/vendor/jquery-ui.min.js"></script>\n<script src="//dd7ihopnvjirc.cloudfront.net./script.js" type="text/javascript"></script>\n<script async="" src="https://cdn.adapex.io/hb/aaw.realgm.js"></script>\n<!-- SendToNews -->\n<script>\r\n   window.addEventListener(\'message\',function(event) { \r\n      if(event.data.type !== \'s2nEvent\' || event.data.s2nEvent !== \'readyToPlay\') {\r\n         return;\r\n      }\r\n      ga(\'send\', {\r\n         hitType: \'event\',\r\n         eventCategory: \'SendtoNews Player\',\r\n         eventAction: \'readyToPlay\',\r\n         eventLabel: event.data.playerKey,\r\n         nonInteraction: true\r\n      });\r\n   });\r\n</script><!-- Admiral Visitor Relationship Management Tag for realgm.com -->\n<script type="text/javascript">!(function(o,_name){o[_name]=o[_name]||function n(){(n.q=n.q||[]).push(arguments)},o[_name].v=o[_name].v||2;!(function(o,t,n,f,e,i){function c(f,e){(f=(function(t,n){try{if(n=(t=o.localStorage).getItem("_aQS01REQzMEI0QTMzQTI2QTZFMjMyODBENjEtMQ"))return JSON.parse(n).lgk||[];if((t.getItem("v4ac1eiZr0")||"").split(",")[4]>0)return[[_name+"-engaged","true"]]}catch(f){}})())&&typeof f.forEach===n&&(e=o[t].pubads())&&f.forEach((function(o){o&&o[0]&&e.setTargeting(o[0],o[1]||"")}))}(i=o[t]=o[t]||{}).cmd=i.cmd||[],typeof i.pubads===n?c():typeof i.cmd.unshift===n?i.cmd.unshift(c):i.cmd.push(c)})(window,"googletag","function");})(window,String.fromCharCode(97,100,109,105,114,97,108) ...

# %%
url
# Out:
# 'https://basketball.realgm.com/nba/teams/Brooklyn-Nets/38/Rosters/Opening_Day/2023'

# %%
OpeningDayRoster(1980)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 OpeningDayRoster(1980)
#
# Cell In[4], line 19, in OpeningDayRoster(year)
#      17     soup = BeautifulSoup(page.content, 'html')
#      18     table = soup.find_all('table')[4]
# ---> 19     dict[' '.join(tm.split('-'))] = pd.read_html(str(table))[0]['Player'].to_list()
#      21 return dict
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/envs/nbaenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Player'

# %% [markdown]
# # Calendar / Schedule

# %%
# This function scrapes the NBA schedule and outputs a dataframe of the calendar for an input year
def Schedule(year) :

    # Scrape every team's information -- number of regular season games & team ID
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_ratings.html'
    soup = BeautifulSoup(requests.get(url).content, 'lxml')
    soup.find('tr', class_ = 'over_header').decompose()
    table = soup.find('table')
    teams_dict = pd.read_html(str(table))[0][['Team', 'W', 'L']]
    teams_dict['code'] = [x['href'].split('/')[2] for x in table.find_all('a', href = True)]
    ngames_dict = dict(zip(teams_dict['code'], teams_dict['W'] + teams_dict['L']))
    teams_dict  = dict(zip(teams_dict['Team'], teams_dict['code']))

    # Scrape the year's schedule page
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games.html'
    soup = BeautifulSoup(requests.get(url).content, 'lxml')
    # Make a list of each month page urls
    monthly_url = [x['href'] for x in soup.find_all('a', href = True) if x['href'].split('.html')[0].split('-')[-1] in months]
    while soup.find('tr', class_ = 'thead') is not None:
        soup.find('tr', class_ = 'thead') .decompose()

    # Concatenate all monthly schedules
    games = pd.read_html(str(soup.find('table')))[0]
    for m_url in monthly_url[1:]:

        url = 'https://www.basketball-reference.com/' + m_url
        soup = BeautifulSoup(requests.get(url).content, 'lxml')
        m_games = pd.read_html(str(soup.find('table')))[0]
        games = pd.concat([games, m_games])
        time.sleep(5)
        

    # Data cleaning
    games = games.rename(columns = {'Start (ET)':'Time', 'Visitor/Neutral':'Away', 'Home/Neutral':'Home', 'PTS':'PTS_away', 'PTS.1':'PTS_home'})
    if 'Time' in games.columns :
        games['Date'] = games['Date'] + games['Time'].apply(lambda x: ' ' + x[:-1] + x[-1].upper() + 'M')
    games['Date'] = pd.to_datetime(games['Date'])
    games = games[['Date', 'Home', 'Away', 'PTS_home', 'PTS_away']] # Keep necessary columns
    games = games.sort_values('Date').reset_index(drop = True)
    games['Home'] = games['Home'].apply(lambda x: teams_dict.get(x))
    games['Away'] = games['Away'].apply(lambda x: teams_dict.get(x))
    games = games[games.index <= sum(ngames_dict.values()) / 2 - 1] # Only keep regular season games

    return games

# %%
Schedule(2023)
# Out:
#                     Date Home Away  PTS_home  PTS_away
# 0    2022-10-18 19:30:00  BOS  PHI       126       117
# 1    2022-10-18 22:00:00  GSW  LAL       123       109
# 2    2022-10-19 19:00:00  DET  ORL       113       109
# 3    2022-10-19 19:00:00  IND  WAS       107       114
# 4    2022-10-19 19:30:00  MIA  CHI       108       116
# ...                  ...  ...  ...       ...       ...
# 1225 2023-04-09 15:30:00  PHO  LAC       114       119
# 1226 2023-04-09 15:30:00  OKC  MEM       115       100
# 1227 2023-04-09 15:30:00  DAL  SAS       117       138
# 1228 2023-04-09 15:30:00  LAL  UTA       128       117
# 1229 2023-04-09 15:30:00  MIN  NOP       113       108
#
# [1230 rows x 5 columns]

# %%
Schedule(1980)
# Out:
#           Date Home Away  PTS_home  PTS_away
# 0   1979-10-12  ATL  NYK       121       104
# 1   1979-10-12  BOS  HOU       114       106
# 2   1979-10-12  DET  IND       114       105
# 3   1979-10-12  KCK  MIL       105       103
# 4   1979-10-12  NJN  CLE       102        95
# ..         ...  ...  ...       ...       ...
# 897 1980-03-30  MIL  UTA       107        91
# 898 1980-03-30  NJN  WSB        87        93
# 899 1980-03-30  PHI  BOS       116       110
# 900 1980-03-30  PHO  SDC       122       104
# 901 1980-03-30  SAS  DET       144       124
#
# [902 rows x 5 columns]
