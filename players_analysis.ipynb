# %% [markdown]
# # Feature Engineering Players

# %%
from functions import Schedule, PlayerStats, OpeningDayRoster
import pandas as pd
import numpy as np

# %%
players = pd.read_csv("data/PlayerStats_withODTm_1979-2023.csv")
players
# Out:
#              PlayerODR  Year OpeningDayTm       clean_name           Player  \
# 0       Tiny Archibald  1979          BOS   TINY ARCHIBALD   Tiny Archibald
# 1        Dennis Awtrey  1979          BOS    DENNIS AWTREY    Dennis Awtrey
# 2        Marvin Barnes  1979          BOS    MARVIN BARNES    Marvin Barnes
# 3           Don Chaney  1979          BOS       DON CHANEY       Don Chaney
# 4          Dave Cowens  1979          BOS      DAVE COWENS      Dave Cowens
# ...                ...   ...          ...              ...              ...
# 17916  Josh Richardson  2023          SAS  JOSH RICHARDSON  Josh Richardson
# 17917      Isaiah Roby  2023          SAS      ISAIAH ROBY      Isaiah Roby
# 17918    Jeremy Sochan  2023          SAS    JEREMY SOCHAN    Jeremy Sochan
# 17919    Devin Vassell  2023          SAS    DEVIN VASSELL    Devin Vassell
# 17920     Blake Wesley  2023          SAS     BLAKE WESLEY     Blake Wesley
#
#             href Pos   Age     G    GS  ...  TOV%  USG%  OWS  DWS   WS  WS/48  \
# 0      architi01  PG  30.0  69.0   NaN  ...  21.8  21.3  1.0  0.6  1.6  0.046
# 1      awtrede01   C  30.0  63.0   NaN  ...  28.3   9.6 -0.1  0.9  0.7  0.046
# 2      barnema01  PF  26.0  38.0   NaN  ...  18.5  18.1  0.1  0.9  1.0  0.060
# 3      chanedo01  SG  32.0  65.0   NaN  ...  13.1  18.1 -0.3  1.0  0.6  0.027
# 4      cowenda01   C  30.0  68.0   NaN  ...  13.7  19.6  2.4  2.4  4.8  0.091
# ...          ...  ..   ...   ...   ...  ...   ...   ...  ...  ...  ...    ...
# 17916  richajo01  SG  29.0  65.0  10.0  ...  12.7  18.4  0.6  1.1  1.8  0.055
# 17917   robyis01  PF  24.0  42.0   2.0  ...  15.2  17.8 -0.4  0.3 -0.1 -0.011
# 17918  sochaje01  PF  19.0  56.0  53.0  ...  13.9  19.8 -0.5  0.7  0.2  0.005
# 17919  vassede01  SG  22.0  38.0  32.0  ...   8.2  24.4  0.7  0.5  1.2  0.051
# 17920  weslebl01  SG  19.0  37.0   1.0  ...  21.7  18.5 -1.9  0.3 -1.6 -0.114
#
#        OBPM  DBPM  BPM  VORP
# 0      -0.5  -2.1 -2.6  -0.3
# 1      -3.5   1.2 -2.3  -0.1
# 2      -2.7   1.2 -1.5   0.1
# 3      -3.5   0.8 -2.7  -0.2
# 4       0.1   0.2  0.3   1.5
# ...     ...   ...  ...   ...
# 17916  -1.0  -0.1 -1.2   0.3
# 17917  -4.0  -0.6 -4.6  -0.3
# 17918  -2.8  -1.2 -4.0  -0.7
# 17919   1.3  -0.9  0.4   0.7
# 17920  -7.9  -1.8 -9.6  -1.3
#
# [17921 rows x 53 columns]

# %%
players.columns
# Out:
# Index(['PlayerODR', 'Year', 'OpeningDayTm', 'clean_name', 'Player', 'href',
#        'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
years = players.Year.unique()
teams = players.OpeningDayTm.unique()

# %% [markdown]
# ### Get Points, Assist, Reb

# %%
window = 5
def get_stats_players(year, team):
    assert len(players[(players.Year == year ) & (players.OpeningDayTm == team)]) > 0, print("Team doesn't exist for this certain Year")
    res = [team, year]
    roster = list(players[(players.Year == year ) & (players.OpeningDayTm == team)].Player)
    # Points for a window of three years
    injury = players[(players.Player.isin(roster)) & (players.Year <= year - 1)][["Player", "G"]]
    games_played = injury.groupby("Player").sum()
    total_games = injury.groupby("Player").count().rename(columns = {"G" : "Total"})
    injury_index = games_played.merge(total_games, how = 'left', on = "Player").reset_index()
    injury_index["InjuryIndex"] = injury_index.apply(lambda x : x.G/(x.Total*82), axis = 1)

    injury_index = injury_index.loc[:, ["Player", "InjuryIndex"]]

    for y in range(window):
        tamp = players[(players.Player.isin(roster)) & (players.Year == year - 1 - y)][["Player", "G", "MP", "PTS", "VORP", "WS", "PER"]]
        tamp = tamp.merge(injury_index, how = "left", on  = "Player")
        tamp["TMP"] = tamp.MP * tamp.G
        tamp = tamp[(tamp.TMP >= 100)]
        total_mp = tamp.MP.sum()
        tamp["weightedPTS"] = tamp.apply(lambda x : (x.MP*x.PTS*x.InjuryIndex), axis = 1)/total_mp
        tamp["weightedVORP"] = tamp.apply(lambda x : (x.MP*x.VORP*x.InjuryIndex), axis = 1)/total_mp
        tamp["weightedPER"] = tamp.apply(lambda x : (x.MP*x.PER*x.InjuryIndex), axis = 1)/total_mp
        tamp["weightedWS"] = tamp.apply(lambda x : (x.MP*x.WS*x.InjuryIndex), axis = 1)/total_mp
        res.append(round(tamp.weightedPTS.sum(), 3))
        res.append(round(tamp.weightedVORP.mean(), 3))
        res.append(round(tamp.weightedPER.mean(), 3))
        res.append(round(tamp.weightedWS.mean(), 3))

    
    return res

# %%
player_features = []
for y in [i for i in range(1984, 2024)]:
    for t in teams: 
        try :
            player_features.append(get_stats_players(y, t))
        except AssertionError:
            pass
col = ["Team", "Year"]
for i in range(window):
    col += [f"MeanPTSWeighted_{i+1}", f"MeanVORP_{i+1}", f"MeanPER_{i+1}", f"MeanWS_{i+1}"]
player_features = pd.DataFrame(player_features, columns = col)
# Out:
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year
# Team doesn't exist for this certain Year

# %%
player_features
# Out:
#      Team  Year  MeanPTSWeighted_1  MeanVORP_1  MeanPER_1  MeanWS_1  \
# 0     BOS  1982             12.352       0.190      1.354     0.569
# 1     NJN  1982             11.698       0.133      1.416     0.377
# 2     NYK  1982             13.052       0.116      1.197     0.409
# 3     WSB  1982             10.073       0.105      1.445     0.427
# 4     ATL  1982             11.279       0.081      1.130     0.312
# ...   ...   ...                ...         ...        ...       ...
# 1130  MEM  2023              9.551       0.094      1.024     0.290
# 1131  OKC  2023              8.059       0.023      0.808     0.097
# 1132  BRK  2023              9.912       0.061      0.770     0.180
# 1133  NOP  2023              9.536       0.061      0.908     0.206
# 1134  CHO  2023              8.847       0.057      0.821     0.198
#
#       MeanPTSWeighted_2  MeanVORP_2  MeanPER_2  MeanWS_2  ...  MeanPER_3  \
# 0                13.011       0.205      1.518     0.655  ...      2.597
# 1                13.596       0.385      2.713     1.012  ...      2.696
# 2                14.605       0.112      1.266     0.393  ...      1.962
# 3                11.452       0.153      2.224     0.713  ...      2.837
# 4                11.434       0.174      1.622     0.588  ...      1.650
# ...                 ...         ...        ...       ...  ...        ...
# 1130              8.416       0.051      1.103     0.228  ...      1.509
# 1131              9.006       0.002      1.222     0.082  ...      1.607
# 1132             10.155       0.084      0.916     0.244  ...      1.028
# 1133             10.709       0.089      1.111     0.263  ...      1.434
# 1134             10.306       0.059      1.103     0.208  ...      1.339
#
#       MeanWS_3  MeanPTSWeighted_4  MeanVORP_4  MeanPER_4  MeanWS_4  \
# 0        0.983              0.000         NaN        NaN       NaN
# 1        0.866              0.000         NaN        NaN       NaN
# 2        0.600              0.000         NaN        NaN       NaN
# 3        0.875              0.000         NaN        NaN       NaN
# 4        0.574              0.000         NaN        NaN       NaN
# ...        ...                ...         ...        ...       ...
# 1130     0.348              8.514       0.204      2.274     0.804
# 1131     0.370              5.527       0.093      2.559     0.540
# 1132     0.260             10.874       0.145      1.075     0.371
# 1133     0.320             10.267       0.085      1.709     0.368
# 1134     0.275              8.706       0.132      2.252     0.501
#
#       MeanPTSWeighted_5  MeanVORP_5  MeanPER_5  MeanWS_5
# 0                 0.000         NaN        NaN       NaN
# 1                 0.000         NaN        NaN       NaN
# 2                 0.000         NaN        NaN       NaN
# 3                 0.000         NaN        NaN       NaN
# 4                 0.000         NaN        NaN       NaN
# ...                 ...         ...        ...       ...
# 1130              8.315       0.178      2.939     1.002
# 1131              4.773       0.377      9.044     1.507
# 1132             12.270       0.239      1.690     0.585
# 1133             10.630       0.155      2.118     0.589
# 1134              8.539       0.152      2.663     0.627
#
# [1135 rows x 22 columns]

# %%
col = list(player_features.columns)[1:]
mean_dataframe = player_features[col].groupby("Year").mean().reset_index()
std_dataframe = player_features[col].groupby("Year").std().reset_index()

# %%
player_features
# Out:
#      Team  Year  MeanPTSWeighted_1  MeanVORP_1  MeanPER_1  MeanWS_1  \
# 0     BOS  1982             12.352       0.190      1.354     0.569
# 1     NJN  1982             11.698       0.133      1.416     0.377
# 2     NYK  1982             13.052       0.116      1.197     0.409
# 3     WSB  1982             10.073       0.105      1.445     0.427
# 4     ATL  1982             11.279       0.081      1.130     0.312
# ...   ...   ...                ...         ...        ...       ...
# 1130  MEM  2023              9.551       0.094      1.024     0.290
# 1131  OKC  2023              8.059       0.023      0.808     0.097
# 1132  BRK  2023              9.912       0.061      0.770     0.180
# 1133  NOP  2023              9.536       0.061      0.908     0.206
# 1134  CHO  2023              8.847       0.057      0.821     0.198
#
#       MeanPTSWeighted_2  MeanVORP_2  MeanPER_2  MeanWS_2  ...  MeanPER_3  \
# 0                13.011       0.205      1.518     0.655  ...      2.597
# 1                13.596       0.385      2.713     1.012  ...      2.696
# 2                14.605       0.112      1.266     0.393  ...      1.962
# 3                11.452       0.153      2.224     0.713  ...      2.837
# 4                11.434       0.174      1.622     0.588  ...      1.650
# ...                 ...         ...        ...       ...  ...        ...
# 1130              8.416       0.051      1.103     0.228  ...      1.509
# 1131              9.006       0.002      1.222     0.082  ...      1.607
# 1132             10.155       0.084      0.916     0.244  ...      1.028
# 1133             10.709       0.089      1.111     0.263  ...      1.434
# 1134             10.306       0.059      1.103     0.208  ...      1.339
#
#       MeanWS_3  MeanPTSWeighted_4  MeanVORP_4  MeanPER_4  MeanWS_4  \
# 0        0.983              0.000         NaN        NaN       NaN
# 1        0.866              0.000         NaN        NaN       NaN
# 2        0.600              0.000         NaN        NaN       NaN
# 3        0.875              0.000         NaN        NaN       NaN
# 4        0.574              0.000         NaN        NaN       NaN
# ...        ...                ...         ...        ...       ...
# 1130     0.348              8.514       0.204      2.274     0.804
# 1131     0.370              5.527       0.093      2.559     0.540
# 1132     0.260             10.874       0.145      1.075     0.371
# 1133     0.320             10.267       0.085      1.709     0.368
# 1134     0.275              8.706       0.132      2.252     0.501
#
#       MeanPTSWeighted_5  MeanVORP_5  MeanPER_5  MeanWS_5
# 0                 0.000         NaN        NaN       NaN
# 1                 0.000         NaN        NaN       NaN
# 2                 0.000         NaN        NaN       NaN
# 3                 0.000         NaN        NaN       NaN
# 4                 0.000         NaN        NaN       NaN
# ...                 ...         ...        ...       ...
# 1130              8.315       0.178      2.939     1.002
# 1131              4.773       0.377      9.044     1.507
# 1132             12.270       0.239      1.690     0.585
# 1133             10.630       0.155      2.118     0.589
# 1134              8.539       0.152      2.663     0.627
#
# [1135 rows x 22 columns]

# %%
def normalizing(year, value, col):
    return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])

for feat in col[1:]:
    player_features[feat] = player_features.apply(lambda x : normalizing(x.Year, x[feat], feat), axis = 1)
player_features
# Out:
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
# /var/folders/x8/gymrgfns32bd6rd_ksf19p3m0000gn/T/ipykernel_8697/2592703399.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   return (value - mean_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])/(std_dataframe[[col, "Year"]][(mean_dataframe.Year == year)].values[0][0])
#      Team  Year  MeanPTSWeighted_1  MeanVORP_1  MeanPER_1  MeanWS_1  \
# 0     BOS  1982           0.348537    1.210192  -0.242138  0.734809
# 1     NJN  1982          -0.069917    0.172885  -0.053946 -0.479048
# 2     NYK  1982           0.796424   -0.136488  -0.718687 -0.276739
# 3     WSB  1982          -1.109654   -0.336670   0.034079 -0.162940
# 4     ATL  1982          -0.338009   -0.773431  -0.922055 -0.889989
# ...   ...   ...                ...         ...        ...       ...
# 1130  MEM  2023           0.067640    0.845879   1.134010  1.035847
# 1131  OKC  2023          -1.312853   -1.257580  -0.693006 -1.678403
# 1132  BRK  2023           0.401660   -0.131785  -1.014426 -0.511134
# 1133  NOP  2023           0.053761   -0.131785   0.152835 -0.145484
# 1134  CHO  2023          -0.583745   -0.250290  -0.583047 -0.257992
#
#       MeanPTSWeighted_2  MeanVORP_2  MeanPER_2  MeanWS_2  ...  MeanPER_3  \
# 0              0.288828    0.281795  -0.504289  0.136557  ...   0.838546
# 1              0.568171    2.105174   1.214595  1.444504  ...   1.023456
# 2              1.049977   -0.660284  -0.866764 -0.823337  ...  -0.347491
# 3             -0.455609   -0.244959   0.511219  0.349052  ...   1.286812
# 4             -0.464204   -0.032231  -0.354695 -0.108912  ...  -0.930237
# ...                 ...         ...        ...       ...  ...        ...
# 1130          -1.045594   -0.503707   0.326551 -0.022412  ...   1.203479
# 1131          -0.619872   -1.770553   1.022616 -2.085271  ...   1.677663
# 1132           0.209203    0.349475  -0.767264  0.203655  ...  -1.123893
# 1133           0.608949    0.478745   0.373346  0.472109  ...   0.840584
# 1134           0.318159   -0.296875   0.326551 -0.304995  ...   0.380915
#
#       MeanWS_3  MeanPTSWeighted_4  MeanVORP_4  MeanPER_4  MeanWS_4  \
# 0     1.187812                NaN         NaN        NaN       NaN
# 1     0.672486                NaN         NaN        NaN       NaN
# 2    -0.499109                NaN         NaN        NaN       NaN
# 3     0.712126                NaN         NaN        NaN       NaN
# 4    -0.613626                NaN         NaN        NaN       NaN
# ...        ...                ...         ...        ...       ...
# 1130  0.886229          -0.788705    0.916165   0.756623  1.899179
# 1131  1.147390          -2.254137   -0.651690   1.150271  0.408497
# 1132 -0.158416           0.369120    0.082801  -0.899460 -0.545766
# 1133  0.553842           0.071324   -0.764689  -0.023767 -0.562705
# 1134  0.019648          -0.694509   -0.100822   0.726236  0.188282
#
#       MeanPTSWeighted_5  MeanVORP_5  MeanPER_5  MeanWS_5
# 0                   NaN         NaN        NaN       NaN
# 1                   NaN         NaN        NaN       NaN
# 2                   NaN         NaN        NaN       NaN
# 3                   NaN         NaN        NaN       NaN
# 4                   NaN         NaN        NaN       NaN
# ...                 ...         ...        ...       ...
# 1130          -0.648207   -0.113884   0.365815  1.085043
# 1131          -1.930911    1.235648   4.329203  2.610185
# 1132           0.784060    0.299792  -0.445040 -0.174332
# 1133           0.190149   -0.269860  -0.167181 -0.162251
# 1134          -0.567088   -0.290204   0.186635 -0.047488
#
# [1135 rows x 22 columns]

# %%
player_features.to_csv("data/player_features.csv", index = None)
